# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df= pd.read_excel("/content/drive/MyDrive/StockPricePrediction.xlsx")
df['Date'] = pd.to_datetime(df['Date'])
print (df)
# Out:
#           Date  Accor S.A.  Thales S.A.   Michelin  Pernod Ricard S.A.  \
# 0   2023-01-19   28.879999   118.000000  28.860001          192.300003
# 1   2023-01-20   29.120001   120.250000  28.290001          191.500000
# 2   2023-01-23   29.139999   121.500000  28.830000          195.050003
# 3   2023-01-24   29.420000   122.900002  28.855000          193.750000
# 4   2023-01-25   29.459999   121.199997  28.870001          193.149994
# ..         ...         ...          ...        ...                 ...
# 505 2025-01-13   46.820000   144.100006  30.900000          104.750000
# 506 2025-01-14   47.509998   145.250000  31.740000          103.949997
# 507 2025-01-15   47.820000   145.350006  32.689999          102.800003
# 508 2025-01-16   47.650002   147.149994  32.490002          104.400002
# 509 2025-01-17   48.060001   148.500000  32.910000          107.400002
#
#      Renault S.A.
# 0       36.500000
# 1       36.480000
# 2       37.290001
# 3       37.334999
# 4       37.264999
# ..            ...
# 505     45.820000
# 506     46.660000
# 507     47.529999
# 508     48.369999
# 509     48.770000
#
# [510 rows x 6 columns]

# %%
plt.figure(figsize=(16,9))
for company in df.columns[1:]:
    plt.plot(df['Date'], df[company], label=company)
plt.legend()
plt.title('Stock Prices for 5 companies from 1/2023 to 1/2025')
plt.ylabel('Closing Price')
plt.xlabel('Time')
plt.grid(True)
plt.show()

# %% [markdown]
# 5. Renault S.A.

# %%
columns_renault = [df.columns[0], df.columns[5]]
df_renault = df[columns_renault]
print(df_renault)
# Out:
#           Date  Renault S.A.
# 0   2023-01-19     36.500000
# 1   2023-01-20     36.480000
# 2   2023-01-23     37.290001
# 3   2023-01-24     37.334999
# 4   2023-01-25     37.264999
# ..         ...           ...
# 505 2025-01-13     45.820000
# 506 2025-01-14     46.660000
# 507 2025-01-15     47.529999
# 508 2025-01-16     48.369999
# 509 2025-01-17     48.770000
#
# [510 rows x 2 columns]

# %%
data_train = df_renault.iloc[0:435,:]
training_set = data_train.iloc[:, 1:2].values
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
X_train = []
y_train = []
no_of_sample = len(training_set)
for i in range(40, no_of_sample):
    X_train.append(training_set_scaled[i-40:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 300, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.01))
regressor.add(LSTM(units = 200, activation = 'tanh', return_sequences = True))
regressor.add(Dropout(0.02))
regressor.add(LSTM(units = 50, activation = 'tanh'))
regressor.add(Dropout(0.01))
regressor.add(Dense(units = 1))
regressor.compile(optimizer=Adam(learning_rate=0.001), loss = 'mean_squared_error')
history= regressor.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_split=0.15)
regressor.save("predictionmodel.h5")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 452ms/step - loss: 0.0716 - val_loss: 0.0258
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 350ms/step - loss: 0.0151 - val_loss: 0.0121
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 319ms/step - loss: 0.0083 - val_loss: 0.0111
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 730ms/step - loss: 0.0084 - val_loss: 0.0138
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - loss: 0.0058 - val_loss: 0.0089
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 554ms/step - loss: 0.0063 - val_loss: 0.0100
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - loss: 0.0056 - val_loss: 0.0094
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 428ms/step - loss: 0.0051 - val_loss: 0.0142
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 508ms/step - loss: 0.0058 - val_loss: 0.0188
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 324ms/step - loss: 0.0054 - val_loss: 0.0126
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 306ms/step - loss: 0.0040 - val_loss: 0.0077
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 488ms/step - loss: 0.0039 - val_loss: 0.0060
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 0.0045 - val_loss: 0.0092
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - loss: 0.0047 - val_loss: 0.0055
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 406ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - loss: 0.0038 - val_loss: 0.0035
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - loss: 0.0042 - val_loss: 0.0060
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 297ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 353ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - loss: 0.0032 - val_loss: 0.0044
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 421ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 308ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 329ms/step - loss: 0.0030 - val_loss: 0.0078
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 490ms/step - loss: 0.0033 - val_loss: 0.0073
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 300ms/step - loss: 0.0032 - val_loss: 0.0060
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 424ms/step - loss: 0.0032 - val_loss: 0.0031
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 302ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 291ms/step - loss: 0.0026 - val_loss: 0.0035
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - loss: 0.0023 - val_loss: 0.0045
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - loss: 0.0026 - val_loss: 0.0048
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 486ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 349ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 415ms/step - loss: 0.0023 - val_loss: 0.0037
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 302ms/step - loss: 0.0025 - val_loss: 0.0042
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 295ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 304ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 286ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 371ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 297ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 363ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 467ms/step - loss: 0.0022 - val_loss: 0.0034
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 296ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 375ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 300ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 292ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 483ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 290ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 443ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 304ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 320ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 432ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 294ms/step - loss: 0.0014 - val_loss: 0.0044
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 309ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 582ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 316ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 305ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 316ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 472ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 306ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 457ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 305ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 301ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 356ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 301ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 410ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 302ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 301ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 455ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 300ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - loss: 0.0017 - val_loss: 0.0053
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 486ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 311ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 408ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 305ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 292ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 295ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 300ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 381ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 305ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 303ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 459ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 297ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 300ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 467ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 301ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 396ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 301ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 308ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 470ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 304ms/step - loss: 0.0014 - val_loss: 0.0015
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
data_test = df_renault.iloc[435:,:]
test_set = data_test.iloc[:, 1:2].values
dataset_total= pd.concat((data_train['Renault S.A.'], data_test['Renault S.A.']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(data_test) - 40:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
no_of_sample = len(inputs)
for i in range(40, no_of_sample):
    X_test.append(inputs[i-40:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price= sc.inverse_transform(predicted_stock_price)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(test_set, predicted_stock_price))
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 0.7337335557838448

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.show()

# %%
plt.plot(test_set, color = 'red', label = 'Real Renault S.A. Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Renault S.A. Stock Price')
plt.title('Renault S.A. Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Renault S.A. Stock Price')
plt.legend()
plt.show()

# %%
dataset_test = df_renault['Renault S.A.'][-40:].to_numpy()
inputs = dataset_test.reshape(-1, 1)
inputs = sc.transform(inputs)

# %%
predictions = []
for i in range(30):
    X_test = inputs[-40:].reshape(1, -1, 1)
    predicted_stock_price = regressor.predict(X_test)
    predicted_stock_price = sc.inverse_transform(predicted_stock_price)
    inputs = np.append(inputs, sc.transform(predicted_stock_price.reshape(-1, 1)), axis=0)
    predictions.append(predicted_stock_price[0][0])
    days = [f'Day {i+1}' for i in range(30)]
predicted_table = pd.DataFrame({
    'Day': days,
    'Predicted Price': predictions })
print(predicted_table)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#        Day  Predicted Price
# 0    Day 1        45.050415
# 1    Day 2        45.038113
# 2    Day 3        45.025917
# 3    Day 4        45.013840
# 4    Day 5        45.001873
# 5    Day 6        44.990013
# 6    Day 7        44.978260
# 7    Day 8        44.966610
# 8    Day 9        44.955067
# 9   Day 10        44.943626
# 10  Day 11        44.932293
# 11  Day 12        44.921055
# 12  Day 13        44.909920
# 13  Day 14        44.898880
# 14  Day 15        44.887939
# 15  Day 16        44.877098
# 16  Day 17        44.866352
# 17  Day 18        44.855701
# 18  Day 19        44.845146
# 19  Day 20        44.834679
# 20  Day 21        44.824306
# 21  Day 22        44.814026
# 22  Day 23        44.803837
# 23  Day 24        44.793732
# 24  Day 25        44.783710
# 25  Day 26        44.773781
# 26  Day 27        44.763939
# 27  Day 28        44.754181
# 28  Day 29        44.744507
# 29  Day 30        44.734913
