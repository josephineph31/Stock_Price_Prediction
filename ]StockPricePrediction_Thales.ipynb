# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df= pd.read_excel("/content/drive/MyDrive/StockPricePrediction.xlsx")
df['Date'] = pd.to_datetime(df['Date'])
print (df)
# Out:
#           Date  Accor S.A.  Thales S.A.   Michelin  Pernod Ricard S.A.  \
# 0   2023-01-19   28.879999   118.000000  28.860001          192.300003
# 1   2023-01-20   29.120001   120.250000  28.290001          191.500000
# 2   2023-01-23   29.139999   121.500000  28.830000          195.050003
# 3   2023-01-24   29.420000   122.900002  28.855000          193.750000
# 4   2023-01-25   29.459999   121.199997  28.870001          193.149994
# ..         ...         ...          ...        ...                 ...
# 505 2025-01-13   46.820000   144.100006  30.900000          104.750000
# 506 2025-01-14   47.509998   145.250000  31.740000          103.949997
# 507 2025-01-15   47.820000   145.350006  32.689999          102.800003
# 508 2025-01-16   47.650002   147.149994  32.490002          104.400002
# 509 2025-01-17   48.060001   148.500000  32.910000          107.400002
#
#      Renault S.A.
# 0       36.500000
# 1       36.480000
# 2       37.290001
# 3       37.334999
# 4       37.264999
# ..            ...
# 505     45.820000
# 506     46.660000
# 507     47.529999
# 508     48.369999
# 509     48.770000
#
# [510 rows x 6 columns]

# %%
plt.figure(figsize=(16,9))
for company in df.columns[1:]:
    plt.plot(df['Date'], df[company], label=company)
plt.legend()
plt.title('Stock Prices for 5 companies from 1/2023 to 1/2025')
plt.ylabel('Closing Price')
plt.xlabel('Time')
plt.grid(True)
plt.show()

# %% [markdown]
# *1*. Thales S.A.

# %%
columns_thales = [df.columns[0], df.columns[2]]
df_thales = df[columns_thales]
print(df_thales)
# Out:
#           Date  Thales S.A.
# 0   2023-01-19   118.000000
# 1   2023-01-20   120.250000
# 2   2023-01-23   121.500000
# 3   2023-01-24   122.900002
# 4   2023-01-25   121.199997
# ..         ...          ...
# 505 2025-01-13   144.100006
# 506 2025-01-14   145.250000
# 507 2025-01-15   145.350006
# 508 2025-01-16   147.149994
# 509 2025-01-17   148.500000
#
# [510 rows x 2 columns]

# %%
data_train = df_thales.iloc[0:435,:]
training_set = data_train.iloc[:, 1:2].values
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
X_train = []
y_train = []
no_of_sample = len(training_set)
for i in range(40, no_of_sample):
    X_train.append(training_set_scaled[i-40:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 300, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.01))
regressor.add(LSTM(units = 200, activation = 'tanh', return_sequences = True))
regressor.add(Dropout(0.01))
regressor.add(LSTM(units = 50, activation = 'tanh'))
regressor.add(Dropout(0.0))
regressor.add(Dense(units = 1))
regressor.compile(optimizer=Adam(learning_rate=0.001), loss = 'mean_squared_error')
history= regressor.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_split=0.15)
regressor.save("predictionmodel.h5")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - loss: 0.1105 - val_loss: 0.0107
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - loss: 0.0126 - val_loss: 0.0027
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - loss: 0.0089 - val_loss: 0.0027
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.0065 - val_loss: 0.0027
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 0.0062 - val_loss: 0.0030
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0055 - val_loss: 0.0031
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 259ms/step - loss: 0.0056 - val_loss: 0.0039
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 0.0047 - val_loss: 0.0028
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - loss: 0.0048 - val_loss: 0.0032
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - loss: 0.0060 - val_loss: 0.0026
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - loss: 0.0053 - val_loss: 0.0023
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - loss: 0.0041 - val_loss: 0.0028
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - loss: 0.0060 - val_loss: 0.0026
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 261ms/step - loss: 0.0039 - val_loss: 0.0022
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - loss: 0.0042 - val_loss: 0.0065
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 0.0051 - val_loss: 0.0041
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - loss: 0.0040 - val_loss: 0.0027
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - loss: 0.0052 - val_loss: 0.0021
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.0043 - val_loss: 0.0020
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - loss: 0.0045 - val_loss: 0.0026
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - loss: 0.0039 - val_loss: 0.0030
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - loss: 0.0037 - val_loss: 0.0040
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - loss: 0.0026 - val_loss: 0.0046
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 219ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 220ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - loss: 0.0023 - val_loss: 0.0017
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 265ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 261ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0021 - val_loss: 0.0041
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - loss: 0.0018 - val_loss: 0.0017
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
data_test = df_thales.iloc[435:,:]
test_set = data_test.iloc[:, 1:2].values
dataset_total= pd.concat((data_train['Thales S.A.'], data_test['Thales S.A.']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(data_test) - 40:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
no_of_sample = len(inputs)
for i in range(40, no_of_sample):
    X_test.append(inputs[i-40:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price= sc.inverse_transform(predicted_stock_price)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(test_set, predicted_stock_price))
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 2.1581402697616134

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.show()

# %%
plt.plot(test_set, color = 'red', label = 'Real Thales S.A. Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Thales S.A. Stock Price')
plt.title('Thales S.A. Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Thales S.A. Stock Price')
plt.legend()
plt.show()

# %%
dataset_test = df_thales['Thales S.A.'][-40:].to_numpy()
inputs = dataset_test.reshape(-1, 1)
inputs = sc.transform(inputs)

# %%
predictions = []
for i in range(30):
    X_test = inputs[-40:].reshape(1, -1, 1)
    predicted_stock_price = regressor.predict(X_test)
    predicted_stock_price = sc.inverse_transform(predicted_stock_price)
    inputs = np.append(inputs, sc.transform(predicted_stock_price.reshape(-1, 1)), axis=0)
    predictions.append(predicted_stock_price[0][0])
    days = [f'Day {i+1}' for i in range(30)]
predicted_table = pd.DataFrame({
    'Day': days,
    'Predicted Price': predictions })
print(predicted_table)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#        Day  Predicted Price
# 0    Day 1       148.904236
# 1    Day 2       149.173843
# 2    Day 3       149.289215
# 3    Day 4       149.369171
# 4    Day 5       149.515259
# 5    Day 6       149.764603
# 6    Day 7       150.107590
# 7    Day 8       150.510269
# 8    Day 9       150.935303
# 9   Day 10       151.355957
# 10  Day 11       151.761139
# 11  Day 12       152.153305
# 12  Day 13       152.542633
# 13  Day 14       152.940598
# 14  Day 15       153.355438
# 15  Day 16       153.790222
# 16  Day 17       154.243439
# 17  Day 18       154.710693
# 18  Day 19       155.186752
# 19  Day 20       155.667160
# 20  Day 21       156.148911
# 21  Day 22       156.630493
# 22  Day 23       157.111298
# 23  Day 24       157.591049
# 24  Day 25       158.069305
# 25  Day 26       158.545212
# 26  Day 27       159.017532
# 27  Day 28       159.484833
# 28  Day 29       159.945541
# 29  Day 30       160.398209
